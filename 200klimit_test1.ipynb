# %%
from o9_common_utils.O9DataLake import O9DataLake, ResourceType, DataSource
query1 = "select (Version.[Version Name]*Product.[Product]*Time.FiscalWeek*SalesAccount.[Account]*Location.[Location]*{Measure.[DPSellOutUnitsActuals],Measure.[Mean Pricing Save PCT],Measure.[Placement Count],Measure.[Promotion Count],Measure.[DPSellOutPrice]});"
O9DataLake.register("sales_df",DataSource.LS, ResourceType.IBPL, query1)
# Out:
#        Version.[Version Name]  Product.[Product] Time.[FiscalWeek]  \
# 0                          S1              85201          W49-2015
# 1          CurrentWorkingView              85201          W49-2015
# 2                          S1              85201          W50-2015
# 3          CurrentWorkingView              85201          W50-2015
# 4                          S1              85201          W51-2015
# ...                       ...                ...               ...
# 199995     CurrentWorkingView             291611          W41-2017
# 199996                     S1             291611          W42-2017
# 199997     CurrentWorkingView             291611          W42-2017
# 199998                     S1             291611          W43-2017
# 199999     CurrentWorkingView             291611          W43-2017
#
#        SalesAccount.[Account] Location.[Location]  DPSellOutUnitsActuals  \
# 0                         ALL                 ALL                    NaN
# 1                         ALL                 ALL                    NaN
# 2                         ALL                 ALL                    NaN
# 3                         ALL                 ALL                    NaN
# 4                         ALL                 ALL                    NaN
# ...                       ...                 ...                    ...
# 199995                    ALL                 ALL                    NaN
# 199996                    ALL                 ALL                  615.0
# 199997                    ALL                 ALL                  615.0
# 199998                    ALL                 ALL                  219.0
# 199999                    ALL                 ALL                  219.0
#
#         Mean Pricing Save PCT  Placement Count  Promotion Count  \
# 0                         NaN              1.0              NaN
# 1                         NaN              1.0              NaN
# 2                         NaN              1.0              NaN
# 3                         NaN              1.0              NaN
# 4                         NaN              1.0              NaN
# ...                       ...              ...              ...
# 199995                    NaN              1.0              NaN
# 199996                    0.2              1.0              1.0
# 199997                    0.2              1.0              1.0
# 199998                    NaN              1.0              NaN
# 199999                    NaN              1.0              NaN
#
#         DPSellOutPrice
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ...                ...
# 199995             NaN
# 199996       24.560976
# 199997       24.560976
# 199998       29.684932
# 199999       29.684930
#
# [200000 rows x 10 columns]

# %%
sales = O9DataLake.get('sales_df')

# %%
sales
# Out:
#        Version.[Version Name]  Product.[Product] Time.[FiscalWeek]  \
# 0                          S1              85201          W49-2015
# 1          CurrentWorkingView              85201          W49-2015
# 2                          S1              85201          W50-2015
# 3          CurrentWorkingView              85201          W50-2015
# 4                          S1              85201          W51-2015
# ...                       ...                ...               ...
# 199995     CurrentWorkingView             291611          W41-2017
# 199996                     S1             291611          W42-2017
# 199997     CurrentWorkingView             291611          W42-2017
# 199998                     S1             291611          W43-2017
# 199999     CurrentWorkingView             291611          W43-2017
#
#        SalesAccount.[Account] Location.[Location]  DPSellOutUnitsActuals  \
# 0                         ALL                 ALL                    NaN
# 1                         ALL                 ALL                    NaN
# 2                         ALL                 ALL                    NaN
# 3                         ALL                 ALL                    NaN
# 4                         ALL                 ALL                    NaN
# ...                       ...                 ...                    ...
# 199995                    ALL                 ALL                    NaN
# 199996                    ALL                 ALL                  615.0
# 199997                    ALL                 ALL                  615.0
# 199998                    ALL                 ALL                  219.0
# 199999                    ALL                 ALL                  219.0
#
#         Mean Pricing Save PCT  Placement Count  Promotion Count  \
# 0                         NaN              1.0              NaN
# 1                         NaN              1.0              NaN
# 2                         NaN              1.0              NaN
# 3                         NaN              1.0              NaN
# 4                         NaN              1.0              NaN
# ...                       ...              ...              ...
# 199995                    NaN              1.0              NaN
# 199996                    0.2              1.0              1.0
# 199997                    0.2              1.0              1.0
# 199998                    NaN              1.0              NaN
# 199999                    NaN              1.0              NaN
#
#         DPSellOutPrice
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ...                ...
# 199995             NaN
# 199996       24.560976
# 199997       24.560976
# 199998       29.684932
# 199999       29.684930
#
# [200000 rows x 10 columns]

# %%
import os
os.environ['COUNTLIMIT'] = '32805416'

# %%
sales = O9DataLake.get('sales_df')

# %%
sales
# Out:
#          Version.[Version Name]  Product.[Product] Time.[FiscalWeek]  \
# 0                            S1              85201          W49-2015
# 1            CurrentWorkingView              85201          W49-2015
# 2                            S1              85201          W50-2015
# 3            CurrentWorkingView              85201          W50-2015
# 4                            S1              85201          W51-2015
# ...                         ...                ...               ...
# 32805411     CurrentWorkingView              79306          W21-2017
# 32805412                     S1              79573          W20-2016
# 32805413     CurrentWorkingView              79573          W20-2016
# 32805414                     S1              79573          W04-2017
# 32805415     CurrentWorkingView              79573          W04-2017
#
#          SalesAccount.[Account] Location.[Location]  DPSellOutUnitsActuals  \
# 0                           ALL                 ALL                    NaN
# 1                           ALL                 ALL                    NaN
# 2                           ALL                 ALL                    NaN
# 3                           ALL                 ALL                    NaN
# 4                           ALL                 ALL                    NaN
# ...                         ...                 ...                    ...
# 32805411                    ALL                 ALL                    2.0
# 32805412                    ALL                 ALL                    1.0
# 32805413                    ALL                 ALL                    1.0
# 32805414                    ALL                 ALL                    1.0
# 32805415                    ALL                 ALL                    1.0
#
#           Mean Pricing Save PCT  Placement Count  Promotion Count  \
# 0                           NaN              1.0              NaN
# 1                           NaN              1.0              NaN
# 2                           NaN              1.0              NaN
# 3                           NaN              1.0              NaN
# 4                           NaN              1.0              NaN
# ...                         ...              ...              ...
# 32805411                    NaN              NaN              NaN
# 32805412                    NaN              NaN              NaN
# 32805413                    NaN              NaN              NaN
# 32805414                    NaN              NaN              NaN
# 32805415                    NaN              NaN              NaN
#
#           DPSellOutPrice
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# ...                  ...
# 32805411             2.0
# 32805412            10.0
# 32805413            10.0
# 32805414            13.0
# 32805415            13.0
#
# [32805416 rows x 10 columns]
